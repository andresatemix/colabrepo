# %% [markdown]
# <a href="https://colab.research.google.com/github/andresatemix/colabrepo/blob/main/neural_net.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

ilmateenistuse_import = pd.read_excel('/content/drive/MyDrive/ColabSheets/Pakri.xlsx', skiprows=2)
ilmateenistuse_import = ilmateenistuse_import.ffill()    

ilmateenistuse_import.head()
# Out:
#    Aasta  Kuu  Päev Kell (UTC)  Õhurõhk merepinna kõrgusel hPa  \
# 0   2004    1     1   00:00:00                          1024.9
# 1   2004    1     1   01:00:00                          1025.1
# 2   2004    1     1   02:00:00                          1025.3
# 3   2004    1     1   03:00:00                          1025.5
# 4   2004    1     1   04:00:00                          1025.3
#
#    Õhurõhk jaama kõrgusel hPa  Tunni sademete summa mm  \
# 0                      1021.9                      NaN
# 1                      1022.1                      NaN
# 2                      1022.3                      NaN
# 3                      1022.6                      NaN
# 4                      1022.4                      NaN
#
#    Suhteline õhuniiskus %  Õhutemperatuur °C  \
# 0                    82.0               -0.5
# 1                    85.0               -1.0
# 2                    90.0               -2.4
# 3                    83.0               -2.4
# ...

# %%
# Maatriksite korrutamine numpy's
import numpy as np
import pprint

matrix_a = np.array([[2, 0], [1, 9]])

matrix_b = np.array([[3, 9], [4, 7]])
korrutis = matrix_a @ matrix_b

pprint.pprint(korrutis)

matrix_c = np.array([[2], [1], [2]])
matrix_d = np.array([[3, 9] ])

korrutis_b = matrix_c @ matrix_d

pprint.pprint(korrutis_b)
# Out:
# array([[ 6, 18],
#        [39, 72]])
# array([[ 6, 18],
#        [ 3,  9],
#        [ 6, 18]])
